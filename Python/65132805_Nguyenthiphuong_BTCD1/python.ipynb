# %%
name = input("what is your name? ")
print("hello, world")
# Out:
# hello, world

# %%
name = input("what is your name? ")
print("hello, name")
# Out:
# hello, name

# %%
name = input("what is your name? ")
print("hello,")
print(name)
# Out:
# hello,
# David

# %%
#ask the user for their name
name = input("what is your name? ")
print("hello,")
print(name)
# Out:
# hello,
# David

# %%
#ask the user for their name
name = input("what is your name? ")
#print hello
print("hello,")
#print the name inputted
print(name)
# Out:
# hello,
# David

# %%
#ask for user for their name
name = input("what is your name? ")
# print hello and the name inputted
print("hello," + name)
# Out:
# hello,David

# %%
#ask the user for their name
name = input("what is your name? ")
#print hello andd inputted name
print("hello, ",name)
# Out:
# hello,  David

# %%
#ask the user for their name
name = input("what is your name? ")
print("hello,")
print(name)
# Out:
# hello,
# David

# %%
#ask the user for their name
name = input("what is your name? ")
print("hello,", end=" ")
print(name)
# Out:
# hello, David

# %%
#ask the user for their name
name = input("what is your name? ")
print(f"hello, {name}")
# Out:
# hello, David

# %%
#ask the user for their name
name = input("what is your name? ")
#remove whitespace from the str
name = name.strip()
#print the output
print(f"hello, {name}")
# Out:
# hello, David

# %%
#ask the user for their name
name = input("what is your name? ")
#remove whitespace from the str
name = name.strip()
#capitalize the first letter of each word
name = name.title()
#print the output
print(f"hello, {name}")
# Out:
# hello, David

# %%
#ask the user for their name, remove whitespace from the str and capitalize the first letter of each word
name = input("what is your name? ").strip().title()
#print the output
print(f"hello, {name}")
# Out:
# hello, David

# %%
x = 1
y = 2
z = x + y
print(z)
# Out:
# 3

# %%
x = input("what's x? ")
y = input("what's y? ")
z = x + y
print(z)
# Out:
# 12

# %%
x = input("what's x? ")
y = input("what's y? ")
z = int(x) + int(y)
print(z)
# Out:
# 3

# %%
X = int(input("what's x? "))
Y = int(input("what's y? "))
print (X + Y)
# Out:
# 3

# %%
x = float(input("what's x? "))
y = float(input("what's y? "))
print (x + y)
# Out:
# 4.6

# %%
#get the user's input
x = float(input("what's x? "))
y = float(input("what's y? "))
#create a rounded result
z = round(x + y)
#print the result
print (z)
# Out:
# 5

# %%
#get the user's input
x = float(input("what's x? "))
y = float(input("what's y? "))
#create a rounded result
z = round(x + y)
#print the formatted result
print (f"{z:,}")
# Out:
# 5

# %%
#get the user's input
x = float(input("what's x? "))
y = float(input("what's y? "))
#calculate the result
z = x/y
#print the result
print (z)
# Out:
# 0.6666666666666666

# %%
#get the user's input
x = float(input("what's x? "))
y = float(input("what's y? "))
#calculate the result and round
z = round(x/y, 2)
#print the result
print (z)
# Out:
# 0.67

# %%
#get the user's input
x = float(input("what's x? "))
y = float(input("what's y? "))
#calculate the result
z = x/y
#print the result
print(f"{z:.2f}")
# Out:
# 0.67

# %%
#ask the user for their name, remove whitespace from the str and capitalize the first letter of each word
name = input("what is your name? ").strip().title()
#print the output
print(f"hello, {name}")
# Out:
# hello, David

# %%
def hello():
    print("hello")
name = input("what' your name? ")
hello()
print(name)
# Out:
# hello
# Daid

# %%
#create our own function
def hello(to):
    print("hello, ",to)
#output using our own function
name = input("what's your name?")
hello(name)
# Out:
# hello,  David

# %%
#create our own function
def hello(to="world"):
    print(f"hello,", to)
#output using our own function
hello(name)
#output wuithout passing the expected argument
hello()
# Out:
# hello, David
# hello, world

# %%
def main():
    #output using our own function
    name = input("what's your name?")
    hello(name)
    #output wuithout passing the expected argument
    hello()
#create our own function
def hello(to="world"):
    print(f"hello,", to)

# %%
def main():
    #output using our own function
    name = input("what's your name?")
    hello(name)
    #output wuithout passing the expected argument
    hello()
#create our own function
def hello(to="world"):
    print(f"hello,", to)
main()
# Out:
# hello, David
# hello, world

# %%
def main():
    x = int(input("what's x? "))
    print("x squared is", squared(x))
def squared(n):
    return n * n
main()
# Out:
# x squared is 4
